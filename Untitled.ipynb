# %%
import pandas as pd

# %%
data=pd.read_csv('train.csv')
data2=pd.read_csv('train.csv')

# %%
data.shape
# Out:
# (38932, 5)

# %%
data.head(5)
# Out:
#    User_ID                                        Description  \
# 0  id10326  The room was kind of clean but had a VERY stro...
# 1  id10327  I stayed at the Crown Plaza April -- - April -...
# 2  id10328  I booked this hotel through Hotwire at the low...
# 3  id10329  Stayed here with husband and sons on the way t...
# 4  id10330  My girlfriends and I stayed here to celebrate ...
#
#         Browser_Used Device_Used Is_Response
# 0               Edge      Mobile   not happy
# 1  Internet Explorer      Mobile   not happy
# 2            Mozilla      Tablet   not happy
# 3   InternetExplorer     Desktop       happy
# 4               Edge      Tablet   not happy

# %%
data.tail(3)
# Out:
#        User_ID                                        Description  \
# 38929  id49255  Traveling with friends for shopping and a show...
# 38930  id49256  The experience was just ok. We paid extra for ...
# 38931  id49257  The Westin is a wonderfully restored grande da...
#
#       Browser_Used Device_Used Is_Response
# 38929      Firefox      Mobile   not happy
# 38930       Chrome     Desktop   not happy
# 38931      Mozilla     Desktop       happy

# %%
data.sample(5)
# Out:
#        User_ID                                        Description  \
# 3177   id13503  i stayed at this hotel in July during a heat w...
# 37650  id47976  Spent - days in NYC with girlfriends. This hot...
# 36721  id47047  I wasn't a big fan of Marriott hotels. In the ...
# 26904  id37230  I stayed here and found this hotel to be very ...
# 8754   id19080  The Paramount Hotel and it's staff did an incr...
#
#            Browser_Used Device_Used Is_Response
# 3177   InternetExplorer     Desktop       happy
# 37650           Firefox     Desktop   not happy
# 36721           Firefox     Desktop       happy
# 26904  InternetExplorer     Desktop       happy
# 8754               Edge      Tablet       happy

# %%
data.describe()
# Out:
#         User_ID                                        Description  \
# count     38932                                              38932
# unique    38932                                              38932
# top     id16344  Arrived late off the plane (--.--pm) and got o...
# freq          1                                                  1
#
#        Browser_Used Device_Used Is_Response
# count         38932       38932       38932
# unique           11           3           2
# top         Firefox     Desktop       happy
# freq           7367       15026       26521

# %%
data.columns
# Out:
# Index(['User_ID', 'Description', 'Browser_Used', 'Device_Used', 'Is_Response'], dtype='object')

# %%
data2['Is_Response'].value_counts()
# Out:
# happy        26521
# not happy    12411
# Name: Is_Response, dtype: int64

# %%
data['Is_Response']=data2['Is_Response'].map({'happy':'baik','not happy':'buruk'})

# %%
data['Is_Response'].value_counts()
# Out:
# baik     26521
# buruk    12411
# Name: Is_Response, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X=data.Description
y=data.Is_Response

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.1, random_state=225)

# %%
print('Banyak data x_train :',len(x_train))
print('Banyak data x_test  :',len(x_test))
print('Banyak data y_train :',len(y_train))
print('Banyak data y_test  :',len(y_test))
# Out:
# Banyak data x_train : 35038
# Banyak data x_test  : 3894
# Banyak data y_train : 35038
# Banyak data y_test  : 3894

# %%
import re
from bs4 import BeautifulSoup
from nltk.tokenize import WordPunctTokenizer


tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9_]+' #menghilangkat username jika twitter
pat2 = r'https?://[^ ]+' #menghilangkan situs website
combined_pat = r'|'.join((pat1, pat2)) #join pat1 dan pat 2
www_pat = r'www.[^ ]+' #menhilangkan situs website

#set_stopword yang di deskripsikan sendiri
#stopword_user = set(pd.read_csv('stopword_usr.txt', sep='\n', header=0).stopword)

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
from spacy.lang.en.stop_words import STOP_WORDS

# %%
ind_stopword = pd.read_csv('stopword_usr.txt', sep='\n', header=None)
ind_stopword.values.tolist()
#ind_stopword
# Out:
# [['kemarin'], ['besok'], ['saya'], ['adalah']]

# %%
def proses_teks(teks):
    soup = BeautifulSoup(teks, 'lxml')
    souped = soup.get_text()
    try:
        teks = souped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        teks = souped
    teks_bersih= re.sub("[^a-zA-Z0-9]", " ",(re.sub(www_pat, '', re.sub(combined_pat, '', teks)).lower()))
    teks_bersih= ' '.join([word for word in teks_bersih.split() if word not in STOP_WORDS])
    return (" ".join([x for x in tok.tokenize(teks_bersih) if len(x) > 1])).strip()

# %%
teks='''hahaha apakah SAYA ingin pergi pada tanggal 15 bulan februari besok ? tidak karena
hari kemarin @twitter suka main https://www.twitter.com'''

# %%
proses_teks(teks)
# Out:
# 'hahaha apakah saya ingin pergi pada tanggal 15 bulan februari besok tidak karena hari kemarin suka main'

# %%
x=[]
for teks in data.Description:
    x.append(proses_teks(teks))

# %%
clean_text=pd.DataFrame({'clean_text':x})

# %%
data=pd.concat([data,clean_text],axis=1)

# %%
data.head(5)
# Out:
#    User_ID                                        Description  \
# 0  id10326  The room was kind of clean but had a VERY stro...
# 1  id10327  I stayed at the Crown Plaza April -- - April -...
# 2  id10328  I booked this hotel through Hotwire at the low...
# 3  id10329  Stayed here with husband and sons on the way t...
# 4  id10330  My girlfriends and I stayed here to celebrate ...
#
#         Browser_Used Device_Used Is_Response  \
# 0               Edge      Mobile       buruk
# 1  Internet Explorer      Mobile       buruk
# 2            Mozilla      Tablet       buruk
# 3   InternetExplorer     Desktop        baik
# 4               Edge      Tablet       buruk
#
#                                           clean_text
# 0  room kind clean strong smell dogs generally av...
# 1  stayed crown plaza april april staff friendly ...
# 2  booked hotel hotwire lowest price find got des...
# 3  stayed husband sons way alaska cruise loved ho...
# 4  girlfriends stayed celebrate th birthdays plan...

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer, HashingVectorizer

# %%
cvec=CountVectorizer()
tvec=TfidfVectorizer()
hvec=HashingVectorizer()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import ComplementNB
from sklearn.naive_bayes import CategoricalNB
from sklearn.svm import SVC

# %%
clf1 = RandomForestClassifier()
clf2 = LogisticRegression(solver='lbfgs', max_iter=400)
clf4 = SVC()
clf3 = BernoulliNB()
clf5 = CategoricalNB() 
clf6 = MultinomialNB()
clf7 = GaussianNB

# %%
from sklearn.pipeline import Pipeline

# %%
model= Pipeline([('vectorizer',tvec)
                 ,('classifier',clf7)])

# %%
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-4719cf73997a> in <module>
# ----> 1 model.fit(x_train,y_train)
#
# c:\users\lalala\appdata\local\programs\python\python37\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     344             if self._final_estimator != 'passthrough':
#     345                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 346                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     347
#     348         return self
#
# TypeError: fit() missing 1 required positional argument: 'y'

# %%
hasil=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
confusion_matrix(hasil,y_test)
# Out:
# array([[2552,  807],
#        [  19,  516]], dtype=int64)

# %%
accuracy_score(hasil,y_test)
# Out:
# 0.7878787878787878

# %%
#save model
#from joblib import dump, load
#dump(model,'sentiment_model.joblib')
