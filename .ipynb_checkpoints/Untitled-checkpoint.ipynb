# %%
import pandas as pd

# %%
#data=pd.read_csv('train.csv')
data=pd.read_excel('questRadikal.xls')

# %%
data2=pd.read_csv('train.csv')

# %%
uu=data2.Description
vv=data2.Is_Response

# %%
uu.shape
# Out:
# (38932,)

# %%
vv.shape
# Out:
# (38932,)

# %%
data.shape
# Out:
# (85, 44)

# %%
data.head(5)
# Out:
#                                               tanya1  \
# 0       Jihad suatu pengorbanan yang dilandasi agama
# 1  jihad adalah perjalanan ke arah yg lebih baik ...
# 2                 Ikhtiar dengan bersungguh sungguh
# 3  jihad adalah suatu hal yang terdapat dalam aga...
# 4                        Membela apa yg perlu dibela
#
#                                               tanya2  \
# 0                Tidak semua tapi ada oknum tertentu
# 1  menurut saya, jihad tidak selalu radikal, hany...
# 2  Menurut saya perbuatan tersebut membuat masyar...
# 3  jihad dapat menjadi bentuk awal radikalisme ji...
# 4                       Karna tidak ada pilihan lain
#
#                                               tanya3  \
# 0                                        Orang jahat
# 1  suatu pandangan yang berlebihan sehingga menim...
# 2  Merupakan perbuatan yang bertolak belakang den...
# 3  radikalisme menurut saya adalah suatu hal yang...
# ...

# %%
data.tail(3)
# Out:
#                                                tanya1  \
# 82         jihad adalah caraberjuang dengan kekerasan
# 83              jihat adalah cara berjuang umat islam
# 84  jihad menurut saya adalah cara membela islam s...
#
#                                                tanya2  \
# 82  dari yang awal nya jihad akan menjadi teroris ...
# 83  jihat adalah masalalu, radikal adalah masa sek...
# 84  menurut saya jihad dan radikal adalah hal yang...
#
#                                                tanya3  \
# 82                          orang yng salah pergaulan
# 83    radikal adalah penyebutan jihad secara sekarang
# 84  radikal merupakan sebuah cara untuk tidak meng...
#
#                                                tanya4  \
# 82               iya karena teroris berfiikir bar bar
# 83  karena teroris pasti radikal, jika tidak tidak...
# 84  iya karena radikal menyebabkan aura negatif ma...
#
#                                                tanya5  \
# ...

# %%
data.sample(5)
# Out:
#                                                tanya1  \
# 51  Menurut saya jihad adalah usaha yang semata-ma...
# 24  Jihad adalah upaya yang dilakukan untuk mencap...
# 8                     perang dalam arti membela agama
# 7   Jihad adalah suatu tindakan yang membela dan b...
# 29  sebuah aktivitas untuk menegakkan agama dan me...
#
#                                                tanya2  \
# 51  Menurut saya benar karena radikalisme adalah p...
# 24  Saya tidak setuju, karena radikalisme dan jiha...
# 8   dapat diketahui sendiri bahwa banyak sekali or...
# 7   Jihad bisa dilakukan dengan hal2 lain yang leb...
# 29  jika dilakukan dengan cara-cara yang melanggar...
#
#                                                tanya3  \
# 51  Radikalisme adalah ideologi tentang kekerasan ...
# 24  Radikalisme adalah suatu pemahaman yang identi...
# 8   suatu paham atau aliran yang menginginkan peru...
# 7   Radikalisme adalah hal yang sangat salah untuk...
# ...

# %%
data.describe()
# Out:
#                                                    tanya1       tanya2  \
# count                                                  85           85
# unique                                                 83           80
# top     jihad adalah pemberontakan terhadap hidup yang...  tidak benar
# freq                                                    2            3
#
#                  tanya3                                             tanya4  \
# count                85                                                 85
# unique               78                                                 83
# top     paham kekerasan  radikalisme mengarah kepada terorisme jika pah...
# freq                  3                                                  2
#
#                                                    tanya5  \
# count                                                  85
# unique                                                 83
# ...

# %%
data.columns
# Out:
# Index(['tanya1', 'tanya2', 'tanya3', 'tanya4', 'tanya5', 'tanya6', 'tanya7',
#        'tanya8', 'tanya9', 'tanya10', 'tanya11', 'tanya12', 'tanya13',
#        'tanya14', 'tanya15', 'tanya16', 'tanya17', 'tanya18', 'tanya19',
#        'tanya20', 'tanya21', 'tanya22', 'tanya23', 'tanya24', 'tanya25',
#        'tanya26', 'tanya27', 'tanya28', 'tanya29', 'tanya30', 'tanya31',
#        'tanya32', 'tanya33', 'tanya34', 'tanya35', 'tanya36', 'tanya37',
#        'tanya38', 'tanya39', 'tanya40', 'tanya41', 'tanya42', 'tanya43',
#        'kelompok'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
Xxx=data.drop(['kelompok'], axis=1)
yyy=data.kelompok

# %%
X_dict = Xxx.to_dict(orient='records')

# %%
Xxx.shape
# Out:
# (85, 43)

# %%
yyy.shape
# Out:
# (85,)

# %%
spamham_countvectorizer.shape
# Out:
# (85, 217)

# %%
x_train, x_test, y_train, y_test = train_test_split(Xxx,yyy,test_size=0.1, random_state=225)

# %%
xx_train, xx_test, yy_train, yy_test = train_test_split(X,y,test_size=0.1, random_state=225)

# %%
print('Banyak data x_train :',len(xx_train))
print('Banyak data x_test  :',len(xx_test))
print('Banyak data y_train :',len(yy_train))
print('Banyak data y_test  :',len(yy_test))
# Out:
# Banyak data x_train : 76
# Banyak data x_test  : 9
# Banyak data y_train : 76
# Banyak data y_test  : 9

# %%
import re
from bs4 import BeautifulSoup
from nltk.tokenize import WordPunctTokenizer


tok = WordPunctTokenizer()
pat1 = r'@[A-Za-z0-9_]+' #menghilangkat username jika twitter
pat2 = r'https?://[^ ]+' #menghilangkan situs website
combined_pat = r'|'.join((pat1, pat2)) #join pat1 dan pat 2
www_pat = r'www.[^ ]+' #menhilangkan situs website

#set_stopword yang di deskripsikan sendiri
#stopword_user = set(pd.read_csv('stopword_usr.txt', sep='\n', header=0).stopword)

# %%
#import spacy
#nlp = spacy.load('en_core_web_sm')
#from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.id.stop_words import STOP_WORDS

# %%
#ind_stopword = pd.read_csv('stopword_usr.txt', sep='\n', header=None)
#ind_stopword.values.tolist()
#ind_stopword
print(list(STOP_WORDS)[:10])
# Out:
# ['nantinya', 'entahlah', 'teringat-ingat', 'menanya', 'sekaligus', 'sesuatunya', 'dikira', 'ketika', 'diucapkan', 'jadi']

# %%
def proses_teks(teks):
    soup = BeautifulSoup(teks, 'lxml')
    souped = soup.get_text()
    try:
        teks = souped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        teks = souped
    teks_bersih= re.sub("[^a-zA-Z0-9]", " ",(re.sub(www_pat, '', re.sub(combined_pat, '', teks)).lower()))
    teks_bersih= ' '.join([word for word in teks_bersih.split() if word not in STOP_WORDS])
    return (" ".join([x for x in tok.tokenize(teks_bersih) if len(x) > 1])).strip()

# %%
#teks='''hahaha apakah SAYA ingin pergi pada tanggal 15 bulan februari besok ? tidak karena
#hari kemarin @twitter suka main https://www.twitter.com'''

# %%
#proses_teks(teks)

# %%
tanya1=[]
for teks in data.tanya1:
    tanya1.append(proses_teks(teks))
tanya2=[]
for teks in data.tanya2:
    tanya2.append(proses_teks(teks))
tanya3=[]
for teks in data.tanya3:
    tanya3.append(proses_teks(teks))
tanya4=[]
for teks in data.tanya4:
    tanya4.append(proses_teks(teks))
tanya5=[]
for teks in data.tanya5:
    tanya5.append(proses_teks(teks))
tanya6=[]
for teks in data.tanya6:
    tanya6.append(proses_teks(teks))
tanya7=[]
for teks in data.tanya7:
    tanya7.append(proses_teks(teks))
tanya8=[]
for teks in data.tanya8:
    tanya8.append(proses_teks(teks))
tanya9=[]
for teks in data.tanya9:
    tanya9.append(proses_teks(teks))
tanya10=[]
for teks in data.tanya10:
    tanya10.append(proses_teks(teks))
tanya11=[]
for teks in data.tanya11:
    tanya11.append(proses_teks(teks))
tanya12=[]
for teks in data.tanya12:
    tanya12.append(proses_teks(teks))
tanya13=[]
for teks in data.tanya13:
    tanya13.append(proses_teks(teks))
tanya14=[]
for teks in data.tanya14:
    tanya14.append(proses_teks(teks))
tanya15=[]
for teks in data.tanya15:
    tanya15.append(proses_teks(teks))
tanya16=[]
for teks in data.tanya16:
    tanya16.append(proses_teks(teks))
tanya17=[]
for teks in data.tanya17:
    tanya17.append(proses_teks(teks))
tanya18=[]
for teks in data.tanya18:
    tanya18.append(proses_teks(teks))
tanya19=[]
for teks in data.tanya19:
    tanya19.append(proses_teks(teks))
tanya20=[]
for teks in data.tanya20:
    tanya20.append(proses_teks(teks))
tanya21=[]
for teks in data.tanya21:
    tanya21.append(proses_teks(teks))
tanya22=[]
for teks in data.tanya22:
    tanya22.append(proses_teks(teks))
tanya23=[]
for teks in data.tanya23:
    tanya23.append(proses_teks(teks))
tanya24=[]
for teks in data.tanya24:
    tanya24.append(proses_teks(teks))
tanya25=[]
for teks in data.tanya25:
    tanya25.append(proses_teks(teks))
tanya26=[]
for teks in data.tanya26:
    tanya26.append(proses_teks(teks))
tanya27=[]
for teks in data.tanya27:
    tanya27.append(proses_teks(teks))
tanya28=[]
for teks in data.tanya28:
    tanya28.append(proses_teks(teks))
tanya29=[]
for teks in data.tanya29:
    tanya29.append(proses_teks(teks))
tanya30=[]
for teks in data.tanya30:
    tanya30.append(proses_teks(teks))
tanya31=[]
for teks in data.tanya31:
    tanya31.append(proses_teks(teks))
tanya32=[]
for teks in data.tanya32:
    tanya32.append(proses_teks(teks))
tanya33=[]
for teks in data.tanya33:
    tanya33.append(proses_teks(teks))
tanya34=[]
for teks in data.tanya34:
    tanya34.append(proses_teks(teks))
tanya35=[]
for teks in data.tanya35:
    tanya35.append(proses_teks(teks))
tanya36=[]
for teks in data.tanya36:
    tanya36.append(proses_teks(teks))
tanya37=[]
for teks in data.tanya37:
    tanya37.append(proses_teks(teks))
tanya38=[]
for teks in data.tanya38:
    tanya38.append(proses_teks(teks))
tanya39=[]
for teks in data.tanya39:
    tanya39.append(proses_teks(teks))
tanya40=[]
for teks in data.tanya40:
    tanya40.append(proses_teks(teks))
tanya41=[]
for teks in data.tanya41:
    tanya41.append(proses_teks(teks))
tanya42=[]
for teks in data.tanya42:
    tanya42.append(proses_teks(teks))
tanya43=[]
for teks in data.tanya43:
    tanya43.append(proses_teks(teks))
# Out:
# c:\users\lalala\appdata\local\programs\python\python37\lib\site-packages\bs4\__init__.py:336: MarkupResemblesLocatorWarning: "..." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   MarkupResemblesLocatorWarning

# %%
tanya_1=pd.DataFrame({'tanya_1':tanya1})
tanya_2=pd.DataFrame({'tanya_2':tanya2})
tanya_3=pd.DataFrame({'tanya_3':tanya3})
tanya_4=pd.DataFrame({'tanya_4':tanya4})
tanya_5=pd.DataFrame({'tanya_5':tanya5})
tanya_6=pd.DataFrame({'tanya_6':tanya6})
tanya_7=pd.DataFrame({'tanya_7':tanya7})
tanya_8=pd.DataFrame({'tanya_8':tanya8})
tanya_9=pd.DataFrame({'tanya_9':tanya9})
tanya_10=pd.DataFrame({'tanya_10':tanya10})
tanya_11=pd.DataFrame({'tanya_11':tanya11})
tanya_12=pd.DataFrame({'tanya_12':tanya12})
tanya_13=pd.DataFrame({'tanya_13':tanya13})
tanya_14=pd.DataFrame({'tanya_14':tanya14})
tanya_15=pd.DataFrame({'tanya_15':tanya15})
tanya_16=pd.DataFrame({'tanya_16':tanya16})
tanya_17=pd.DataFrame({'tanya_17':tanya17})
tanya_18=pd.DataFrame({'tanya_18':tanya18})
tanya_19=pd.DataFrame({'tanya_19':tanya19})
tanya_20=pd.DataFrame({'tanya_20':tanya20})
tanya_21=pd.DataFrame({'tanya_21':tanya21})
tanya_22=pd.DataFrame({'tanya_22':tanya22})
tanya_23=pd.DataFrame({'tanya_23':tanya23})
tanya_24=pd.DataFrame({'tanya_24':tanya24})
tanya_25=pd.DataFrame({'tanya_25':tanya25})
tanya_26=pd.DataFrame({'tanya_26':tanya26})
tanya_27=pd.DataFrame({'tanya_27':tanya27})
tanya_28=pd.DataFrame({'tanya_28':tanya28})
tanya_29=pd.DataFrame({'tanya_29':tanya29})
tanya_30=pd.DataFrame({'tanya_30':tanya30})
tanya_31=pd.DataFrame({'tanya_31':tanya31})
tanya_32=pd.DataFrame({'tanya_32':tanya32})
tanya_33=pd.DataFrame({'tanya_33':tanya33})
tanya_34=pd.DataFrame({'tanya_34':tanya34})
tanya_35=pd.DataFrame({'tanya_35':tanya35})
tanya_36=pd.DataFrame({'tanya_36':tanya36})
tanya_37=pd.DataFrame({'tanya_37':tanya37})
tanya_38=pd.DataFrame({'tanya_38':tanya38})
tanya_39=pd.DataFrame({'tanya_39':tanya39})
tanya_40=pd.DataFrame({'tanya_40':tanya40})
tanya_41=pd.DataFrame({'tanya_41':tanya41})
tanya_42=pd.DataFrame({'tanya_42':tanya42})
tanya_43=pd.DataFrame({'tanya_43':tanya43})

# %%
tanya_32=pd.DataFrame({'tanya_32':tanya32})

# %%
tanya_1.sample(5)
# Out:
#                                   tanya_1
# 61  jihad tindakan berjuang membela agama
# 74          berjuang mempertahankan agama
# 7   jihad tindakan membela berjuang agama
# 4                          membela dibela
# 30                          membela agama

# %%
newdata=pd.concat([tanya_1,tanya_2,tanya_3,tanya_4,tanya_5,tanya_6,tanya_7,tanya_8,tanya_9,tanya_10,tanya_11,tanya_12,tanya_13,tanya_14,tanya_15,tanya_16,tanya_17,tanya_18,tanya_19,tanya_20,tanya_21,tanya_22,tanya_23,tanya_24,tanya_25,tanya_26,tanya_27,tanya_28,tanya_29,tanya_30,tanya_31,tanya_32,tanya_33,tanya_34,tanya_35,tanya_36,tanya_37,tanya_38,tanya_39,tanya_40,tanya_41,tanya_42,tanya_43],axis=1)

# %%
newdata.sample(5)
# Out:
#                                        tanya_1  \
# 35                 menjaga agama allah berdiri
# 66          jihad bentuk pembelaan agama islam
# 21                   kegiatan membela agamanya
# 18               memperjuangkan agama diyakini
# 45  jihad pengorbanan mata membela agama allah
#
#                                               tanya_2  \
# 35                             tergantung makna jihad
# 66              setuju jihad dibarengi ilmu berdampak
# 21                           jihad bentuk radikalisme
# 18  orang terpengaruh radikal beranggapan radikal ...
# 45  jihad radikalisme berbeda makna jihad bentuk r...
#
#                                               tanya_3  \
# 35                            faham identik kekerasan
# 66                       radikalisme bersifat memaksa
# 21                   gerakan menimbulkan aksi anarkis
# 18              miris namanya jelek personal agamanya
# 45  radikalisme paham perubahan pembaharuan sosial...
#
# ...

# %%
#data setelah vektorizer
X=newdata
y=data.kelompok

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
tanya_countvectorizer = vectorizer.fit_transform(X['tanya_1']+' '+['tanya_2']+' '+['tanya_3']+' '+['tanya_4']+' '+['tanya_5']+' '+['tanya_6']+' '+['tanya_7']+' '+['tanya_8']+' '+['tanya_9']+' '+['tanya_10']+' '+['tanya_11']+' '+['tanya_12']+' '+['tanya_13']+' '+['tanya_14']+' '+['tanya_15']+' '+['tanya_16']+' '+['tanya_17']+' '+['tanya_18']+' '+['tanya_20']+' '+['tanya_21']+' '+['tanya_22']+' '+['tanya_23']+' '+['tanya_24']+' '+['tanya_25']+' '+['tanya_26']+' '+['tanya_27']+' '+['tanya_28']+' '+['tanya_29']+' '+['tanya_30']+' '+['tanya_31']+' '+['tanya_32']+' '+['tanya_33']+' '+['tanya_34']+' '+['tanya_35']+' '+['tanya_36']+' '+['tanya_37']+' '+['tanya_38']+' '+['tanya_39']+' '+['tanya_40']+' '+['tanya_41']+' '+['tanya_42']+' '+['tanya_43'])

# %%
test_data = vectorizer.transform(Xxx['tanya1']+' '+['tanya2']+' '+['tanya3']+' '+['tanya4']+' '+['tanya5']+' '+['tanya6']+' '+['tanya7']+' '+['tanya8']+' '+['tanya9']+' '+['tanya10']+' '+['tanya11']+' '+['tanya12']+' '+['tanya13']+' '+['tanya14']+' '+['tanya15']+' '+['tanya16']+' '+['tanya17']+' '+['tanya18']+' '+['tanya20']+' '+['tanya21']+' '+['tanya22']+' '+['tanya23']+' '+['tanya24']+' '+['tanya25']+' '+['tanya26']+' '+['tanya27']+' '+['tanya28']+' '+['tanya29']+' '+['tanya30']+' '+['tanya31']+' '+['tanya32']+' '+['tanya33']+' '+['tanya34']+' '+['tanya35']+' '+['tanya36']+' '+['tanya37']+' '+['tanya38']+' '+['tanya39']+' '+['tanya40']+' '+['tanya41']+' '+['tanya42']+' '+['tanya43'])

# %%
test_data.shape
# Out:
# (85, 257)

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
v = DictVectorizer(sparse=False)
D = [{'foo': 1, 'bar': 2}, {'foo': 3, 'baz': 1}]
Xx = v.fit_transform(D)
Xx
# Out:
# array([[2., 0., 1.],
#        [0., 1., 3.]])

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer, HashingVectorizer

# %%
cvec=CountVectorizer()
tvec=TfidfVectorizer()
hvec=HashingVectorizer()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import ComplementNB
from sklearn.naive_bayes import CategoricalNB
from sklearn.svm import SVC

# %%
clf1 = RandomForestClassifier()
clf2 = LogisticRegression(solver='lbfgs', max_iter=400)
clf4 = SVC()
clf3 = BernoulliNB()
clf5 = CategoricalNB() 
clf6 = MultinomialNB()
clf7 = GaussianNB

# %%
from sklearn.pipeline import Pipeline

# %%
#model= Pipeline([('vectorizer',cvec)
#                 ,('classifier',clf6)])
model=clf6.fit(tanya_countvectorizer,yyy)

# %%
hasil= model.predict(test_data)
hasil
# Out:
# array(['rendah', 'rendah', 'rendah', 'rendah', 'rendah', 'rendah',
#        'rendah', 'menengah', 'rendah', 'rendah', 'rendah', 'rendah',
#        'rendah', 'rendah', 'rendah', 'rendah', 'rendah', 'rendah',
#        'rendah', 'rendah', 'rendah', 'rendah', 'rendah', 'rendah',
#        'tinggi', 'rendah', 'rendah', 'menengah', 'menengah', 'menengah',
#        'rendah', 'menengah', 'menengah', 'menengah', 'menengah',
#        'menengah', 'tinggi', 'menengah', 'menengah', 'menengah',
#        'menengah', 'menengah', 'menengah', 'menengah', 'menengah',
#        'menengah', 'menengah', 'menengah', 'rendah', 'menengah',
#        'menengah', 'menengah', 'menengah', 'menengah', 'rendah', 'tinggi',
#        'tinggi', 'tinggi', 'tinggi', 'rendah', 'rendah', 'menengah',
#        'rendah', 'tinggi', 'tinggi', 'tinggi', 'tinggi', 'tinggi',
#        'tinggi', 'tinggi', 'tinggi', 'menengah', 'tinggi', 'tinggi',
#        'menengah', 'rendah', 'tinggi', 'tinggi', 'tinggi', 'tinggi',
# ...

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cm=confusion_matrix(hasil,yyy)
sns.heatmap(cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
accuracy_score(yyy,hasil)
# Out:
# 0.8470588235294118

# %%
print(classification_report(yyy,hasil))
# Out:
#               precision    recall  f1-score   support
#
#     menengah       0.86      0.86      0.86        28
#       rendah       0.78      0.93      0.85        27
#       tinggi       0.92      0.77      0.84        30
#
#     accuracy                           0.85        85
#    macro avg       0.85      0.85      0.85        85
# weighted avg       0.86      0.85      0.85        85

# %%
#save model
#from joblib import dump, load
#dump(model,'sentiment_model.joblib')
#import pickle
#filename = 'sentiment_model.sav'
#pickle.dump(model, open(filename, 'wb'))

# %%
#load model
#loaded_model = pickle.load(open(filename, 'rb'))
#result = loaded_model.predict(test_data)
#result
# Out:
# array(['rendah', 'rendah', 'rendah', 'rendah', 'rendah', 'rendah',
#        'rendah', 'menengah', 'rendah', 'rendah', 'rendah', 'rendah',
#        'rendah', 'rendah', 'rendah', 'rendah', 'rendah', 'rendah',
#        'rendah', 'rendah', 'rendah', 'rendah', 'rendah', 'rendah',
#        'tinggi', 'rendah', 'rendah', 'menengah', 'menengah', 'menengah',
#        'rendah', 'menengah', 'menengah', 'menengah', 'menengah',
#        'menengah', 'tinggi', 'menengah', 'menengah', 'menengah',
#        'menengah', 'menengah', 'menengah', 'menengah', 'menengah',
#        'menengah', 'menengah', 'menengah', 'rendah', 'menengah',
#        'menengah', 'menengah', 'menengah', 'menengah', 'rendah', 'tinggi',
#        'tinggi', 'tinggi', 'tinggi', 'rendah', 'rendah', 'menengah',
#        'rendah', 'tinggi', 'tinggi', 'tinggi', 'tinggi', 'tinggi',
#        'tinggi', 'tinggi', 'tinggi', 'menengah', 'tinggi', 'tinggi',
#        'menengah', 'rendah', 'tinggi', 'tinggi', 'tinggi', 'tinggi',
# ...
